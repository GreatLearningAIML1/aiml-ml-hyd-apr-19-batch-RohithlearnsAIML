# %% [markdown]
# # Sentiment Classification
#
#
# ### Generate Word Embeddings and retrieve outputs of each layer with Keras based on Classification task
#
# Word embeddings are a type of word representation that allows words with similar meaning to have a similar representation.
#
# It is a distributed representation for text that is perhaps one of the key breakthroughs for the impressive performance of deep learning methods on challenging natural language processing problems.
#
# We willl use the imdb dataset to learn word embeddings as we train our dataset. This dataset contains 25,000 movie reviews from IMDB, labeled with sentiment (positive or negative).
#
#
#
# ### Dataset
#
# `from keras.datasets import imdb`
#
# Dataset of 25,000 movies reviews from IMDB, labeled by sentiment (positive/negative). Reviews have been preprocessed, and each review is encoded as a sequence of word indexes (integers). For convenience, the words are indexed by their frequency in the dataset, meaning the for that has index 1 is the most frequent word. Use the first 20 words from each review to speed up training, using a max vocab size of 10,000.
#
# As a convention, "0" does not stand for a specific word, but instead is used to encode any unknown word.
#
#
# ### Aim
#
# 1. Import test and train data
# 2. Import the labels ( train and test)
# 3. Get the word index and then Create key value pair for word and word_id. (12.5 points)
# 4. Build a Sequential Model using Keras for Sentiment Classification task. (10 points)
# 5. Report the Accuracy of the model. (5 points)
# 6. Retrive the output of each layer in keras for a given single test sample from the trained model you built. (2.5 points)

# %% [markdown]
# #### Usage:

# %%
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
import numpy as np

# %%
import numpy as np
# save np.load
np_load_old = np.load

# modify the default parameters of np.load
np.load = lambda *a,**k: np_load_old(*a, allow_pickle=True, **k)

# %%
from keras.datasets import imdb

vocab_size = 10000 #vocab size

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size) # vocab_size is no.of words to consider from the dataset, ordering based on frequency.
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 17473536/17464789 [==============================] - 0s 0us/step

# %%
np.load = np_load_old

# %%
from keras.preprocessing.sequence import pad_sequences
vocab_size = 10000 #vocab size
maxlen = 300  #number of word used from each review

# %%
#make all sequences of the same length
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test =  pad_sequences(x_test, maxlen=maxlen)

# %%
x_train.shape
# Out:
# (25000, 300)

# %%
x_test.shape
# Out:
# (25000, 300)

# %%
y_train
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
x_train
# Out:
# array([[   0,    0,    0, ...,   19,  178,   32],
#        [   0,    0,    0, ...,   16,  145,   95],
#        [   0,    0,    0, ...,    7,  129,  113],
#        ...,
#        [   0,    0,    0, ...,    4, 3586,    2],
#        [   0,    0,    0, ...,   12,    9,   23],
#        [   0,    0,    0, ...,  204,  131,    9]], dtype=int32)

# %%
#Get the word index and then Create key value pair for word and word_id. (12.5 points)

# %%
word_index=imdb.get_word_index()
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step
# 1654784/1641221 [==============================] - 0s 0us/step

# %%
word_index
# Out:
# {u'fawn': 34701,
#  u'tsukino': 52006,
#  u'nunnery': 52007,
#  u'sonja': 16816,
#  u'vani': 63951,
#  u'woods': 1408,
#  u'spiders': 16115,
#  u'hanging': 2345,
#  u'woody': 2289,
#  u'trawling': 52008,
#  u"hold's": 52009,
#  u'comically': 11307,
#  u'localized': 40830,
#  u'disobeying': 30568,
#  u"'royale": 52010,
#  u"harpo's": 40831,
#  u'canet': 52011,
#  u'aileen': 19313,
#  u'acurately': 52012,
#  u"diplomat's": 52013,
#  u'rickman': 25242,
#  u'rumbustious': 52014,
#  u'familiarness': 52015,
#  u"spider'": 52016,
#  u'hahahah': 68804,
#  u"wood'": 52017,
#  u'transvestism': 40833,
#  u"hangin'": 34702,
#  u'screaming': 1927,
#  u'seamier': 40834,
#  u'wooded': 34703,
#  u'bravora': 52018,
#  u'grueling': 16817,
#  u'wooden': 1636,
#  u'wednesday': 16818,
#  u"'prix": 52019,
#  u'altagracia': 34704,
#  u'circuitry': 52020,
#  u'crotch': 11585,
#  u'busybody': 57766,
#  u"tart'n'tangy": 52021,
#  u'pantheistic': 52022,
#  u'thrace': 52023,
#  u"tom's": 11038,
#  u'snuggles': 52025,
#  u"frasier's": 52026,
#  u'complainers': 52027,
#  u'templarios': 52125,
#  u'272': 40835,
#  u'273': 52028,
#  u'zaniacs': 52130,
#  u'275': 34706,
#  u'consenting': 27631,
#  u'snuggled': 40836,
#  u'inanimate': 15492,
#  u'uality': 52030,
#  u'bronte': 11926,
#  u'errors': 4010,
#  u'dialogs': 3230,
#  u'hp': 23593,
#  u"yomada's": 52031,
#  u"madman's": 34707,
#  u'dialoge': 30585,
#  u'usenet': 52033,
#  u'videodrome': 40837,
#  u"kid'": 26338,
#  u'pawed': 52034,
#  u"'girlfriend'": 30569,
#  u"'pleasure": 52035,
#  u"'reloaded'": 52036,
#  u"kazakos'": 40839,
#  u'rocque': 52037,
#  u'mailings': 52038,
#  u'brainwashed': 11927,
#  u'mcanally': 16819,
#  u"tom''": 52039,
#  u'kurupt': 25243,
#  u'affiliated': 21905,
#  u'babaganoosh': 52040,
#  u"noe's": 40840,
#  u'quart': 40841,
#  u'kids': 359,
#  u'uplifting': 5034,
#  u'controversy': 7093,
#  u'kida': 21906,
#  u'kidd': 23379,
#  u"error'": 52041,
#  u'neurologist': 52042,
#  u'spotty': 18510,
#  u'cobblers': 30570,
#  u'projection': 9878,
#  u'fastforwarding': 40842,
#  u'sters': 52043,
#  u"eggar's": 52044,
#  u'etherything': 52045,
#  u'airball': 34708,
#  u'unsinkable': 25244,
#  u'stern': 7180,
#  u"cervi's": 52046,
#  u'dnd': 40844,
#  u'dna': 11586,
#  u'insecurity': 20598,
#  u"'reboot'": 52047,
#  u'trelkovsky': 11037,
#  u'jaekel': 52048,
#  u'sidebars': 52049,
#  u"sforza's": 52050,
#  u'distortions': 17633,
#  u"bynes'": 69999,
#  u'sermons': 30602,
#  u'7ft': 40846,
#  u'boobage': 52052,
#  u"o'bannon's": 52053,
#  u'populations': 23380,
#  u'chulak': 52054,
#  u'mesmerize': 27633,
#  u'quinnell': 52055,
#  u'yahoo': 10307,
#  u'peahi': 52056,
#  u'meteorologist': 52057,
#  u'beswick': 42577,
#  u'boorman': 15493,
#  u'ravensbr\xfcck': 51678,
#  u'voicework': 40847,
#  u"ster'": 52058,
#  u'blustering': 22922,
#  u'intake': 27634,
#  u'morally': 5621,
#  u'sky\xa1\xa8': 69580,
#  u'jumbling': 40849,
#  u'bowersock': 52060,
#  u"'porky's'": 52061,
#  u'gershon': 16821,
#  u'ludicrosity': 40850,
#  u'coprophilia': 52062,
#  u'expressively': 40851,
#  u"india's": 19500,
#  u"post's": 34710,
#  u'wana': 52063,
#  u'wang': 5283,
#  u'wand': 30571,
#  u'wane': 25245,
#  u'disparagement': 52064,
#  u'titanium': 34711,
#  u'pinta': 40852,
#  u'want': 178,
#  u'pinto': 30572,
#  u'whoopdedoodles': 52065,
#  u'tchaikovsky': 21908,
#  u'travel': 2103,
#  u"'victory'": 52066,
#  u'copious': 11928,
#  u"chapters'": 52067,
#  u'barbra': 6702,
#  u'uselessness': 30573,
#  u"wan'": 52068,
#  u'assimilated': 27635,
#  u'petiot': 16116,
#  u'dinosaurs': 3930,
#  u'wrong': 352,
#  u'seda': 52070,
#  u'stollen': 52071,
#  u'sentencing': 34712,
#  u'ouroboros': 40853,
#  u'assimilates': 40854,
#  u'colorfully': 40855,
#  u'glenne': 27636,
#  u"'caricature'": 70418,
#  u'subplots': 4760,
#  u'kiloton': 52073,
#  u'chandon': 23381,
#  u"effect'": 34713,
#  u'flawlessness': 88437,
#  u'snugly': 27637,
#  u'kuei': 40856,
#  u'welcomed': 9092,
#  u'dishonor': 30071,
#  u'concurrence': 52075,
#  u'stoicism': 23382,
#  u"beroemd'": 52077,
#  u'butcher': 6703,
#  u"melfi's": 40857,
#  u'aargh': 30623,
#  u'playhouse': 20599,
#  u'wickedly': 11308,
#  u'fit': 1180,
#  u'labratory': 52078,
#  u'lifeline': 40859,
#  u'bringing': 2338,
#  u'fix': 4287,
#  u'cineliterate': 52079,
#  u'fic': 52080,
#  u'fia': 52081,
#  u'fig': 34714,
#  u'fmvs': 52082,
#  u'fie': 52083,
#  u'reentered': 52084,
#  u'fin': 30574,
#  u'doctresses': 52085,
#  u'fil': 52086,
#  u'zucker': 12606,
#  u'ached': 31931,
#  u'counsil': 52088,
#  u'paterfamilias': 52089,
#  u'songwriter': 13885,
#  u'shivam': 34715,
#  u'hurting': 9654,
#  u'effects': 299,
#  u'kid\xf4': 83921,
#  u'slauther': 52090,
#  u"'flame'": 52091,
#  u'broiler': 70420,
#  u'interwhined': 52093,
#  u'whacking': 27638,
#  u'bartok': 52094,
#  u'barton': 8775,
#  u'frewer': 21909,
#  u"fi'": 52095,
#  u'ingrid': 6192,
#  u'stribor': 30575,
#  u'approporiately': 52096,
#  u'wobblyhand': 52097,
#  u'tantalisingly': 52098,
#  u'ankylosaurus': 52099,
#  u'parasites': 17634,
#  u'childen': 52100,
#  u"jenkins'": 52101,
#  u'metafiction': 52102,
#  u'golem': 17635,
#  u'indiscretion': 40860,
#  u"reeves'": 23383,
#  u"inamorata's": 57781,
#  u'brittannica': 52104,
#  u'adapt': 7916,
#  u"russo's": 30576,
#  u'guitarists': 48246,
#  u'abbott': 10553,
#  u'abbots': 40861,
#  u'lanisha': 17649,
#  u'magickal': 40863,
#  u'mattter': 52105,
#  u"'willy": 52106,
#  u'pumpkins': 34716,
#  u'stuntpeople': 52107,
#  u'fi\x85': 84457,
#  u'estimate': 30577,
#  u'ugghhh': 40864,
#  u'gameplay': 11309,
#  u"wern't": 52108,
#  u'rebels\x85': 84863,
#  u"n'sync": 40865,
#  u'sickeningly': 16117,
#  u'chiara': 40866,
#  u'disturbed': 4011,
#  u'portmanteau': 40867,
#  u'ineffectively': 52109,
#  u"duchonvey's": 82143,
#  u"nasty'": 37519,
#  u'purpose': 1285,
#  u'lazers': 52112,
#  u'breed': 5284,
#  u'kaliganj': 52113,
#  u'popularism': 52114,
#  u"damme's": 18511,
#  u'stylistics': 30578,
#  u'mindgaming': 52115,
#  u"1997'": 52116,
#  u"'corny'": 52117,
#  u'boerner': 34718,
#  u'olds': 6792,
#  u'bakelite': 52118,
#  u'renovated': 27639,
#  u'forrester': 27640,
#  u'timid': 12004,
#  u'gaskets': 52024,
#  u'needed': 884,
#  u'smight': 34719,
#  u'master': 1297,
#  u"edie's": 25905,
#  u'seeber': 40868,
#  u'hiya': 52120,
#  u'fuzziness': 52121,
#  u'genesis': 14897,
#  u'rewards': 12607,
#  u'enthrall': 30579,
#  u'nemesis\x85': 54439,
#  u'splendiferous': 53089,
#  u"recollection's": 52122,
#  u'mutilated': 11039,
#  u'fatherlands': 52123,
#  u"fischer's": 52124,
#  u'positively': 5399,
#  u'270': 34705,
#  u'ahmed': 34720,
#  u'zatoichi': 9836,
#  u'miniatures': 20046,
#  u'anniversaries': 52127,
#  u"helm's": 30580,
#  u"'work'": 52128,
#  u'exclaimed': 34721,
#  u"'unfunny'": 52129,
#  u'274': 52029,
#  u'feeling': 544,
#  u"wanda's": 52131,
#  u'dolan': 33266,
#  u'kiernan': 46193,
#  u'278': 52133,
#  u'peacoat': 52134,
#  u'brawny': 40870,
#  u'mishra': 40871,
#  u'worlders': 40872,
#  u'protags': 52135,
#  u'skullcap': 52136,
#  u'pompous': 8288,
#  u'affairs': 5622,
#  u'wholesome': 7799,
#  u'hymen': 52137,
#  u'paramedics': 25246,
#  u'unpersons': 52138,
#  u'heavyarms': 52139,
#  u'affaire': 52140,
#  u'coulisses': 52141,
#  u'hymer': 40873,
#  u'kremlin': 52142,
#  u'shipments': 30581,
#  u'pixilated': 52143,
#  u"'00s": 30582,
#  u'diminishing': 18512,
#  u'cinematic': 1357,
#  u'resonates': 14898,
#  u'simplify': 40874,
#  u'tensely': 70427,
#  u'temptresses': 40876,
#  u'reverence': 16822,
#  u'resonated': 19502,
#  u'dailey': 34722,
#  u'attach\xe9s': 42050,
#  u'treize': 27641,
#  u'majo': 52145,
#  u'kiya': 21910,
#  u'woolnough': 52146,
#  u'thanatos': 39797,
#  u'plays\x85jack': 55347,
#  u'sandoval': 35731,
#  u'dorama': 40879,
#  u"o'shaughnessy": 52147,
#  u'tech': 4988,
#  u'fugitives': 32018,
#  u'teck': 30583,
#  u'purged': 52149,
#  u'saying': 657,
#  u"martians'": 41095,
#  u'norliss': 23418,
#  u'dickey': 27642,
#  u'dicker': 52152,
#  u"'sependipity": 52153,
#  u'padded': 8422,
#  u'ordell': 57792,
#  u"sturges'": 40882,
#  u'independentcritics': 52154,
#  u'tempted': 5745,
#  u"atkinson's": 34724,
#  u'hounded': 25247,
#  u'apace': 52155,
#  u'clicked': 15494,
#  u"'humor'": 30584,
#  u"martino's": 17177,
#  u"'supporting": 52156,
#  u'warmongering': 52032,
#  u"zemeckis's": 34725,
#  u'lube': 21911,
#  u"ernest's": 70431,
#  u'plate': 7476,
#  u'plata': 40883,
#  u'sturgess': 40884,
#  u"nerds'": 40885,
#  u'plato': 20600,
#  u'plath': 34726,
#  u'platt': 40886,
#  u'mcnab': 52159,
#  u'clumsiness': 27643,
#  u'altogether': 3899,
#  u'rugged': 9093,
#  u'bicenntinial': 52160,
#  u'skaal': 40887,
#  u'droning': 14360,
#  u'lds': 8776,
#  u'jaguar': 21912,
#  u"cale's": 34727,
#  u'nicely': 1777,
#  u'patch': 10086,
#  u'kerkhof': 50202,
#  u"leader's": 52161,
#  u'seriously\x85': 49806,
#  u'circling': 19503,
#  u"'movie": 27644,
#  u'uncomfirmed': 52162,
#  u'heirloom': 40888,
#  u"'stargate'": 52164,
#  u'pinoy': 40889,
#  u'conchatta': 40890,
#  u'broeke': 41128,
#  u'advisedly': 40891,
#  u"barker's": 17636,
#  u'descours': 52166,
#  u'lots': 772,
#  u'lotr': 9259,
#  u'irs': 9879,
#  u'lott': 52167,
#  u'xvi': 40892,
#  u'irk': 34728,
#  u'irl': 52168,
#  u'ira': 6887,
#  u'belzer': 21913,
#  u'irc': 52169,
#  u'ire': 27645,
#  u'requisites': 40893,
#  u'discipline': 7693,
#  u'lyoko': 52961,
#  u'extend': 11310,
#  u'nature': 873,
#  u"'dickie'": 52170,
#  u'fruits': 21460,
#  u'lapping': 30586,
#  u'superficial': 3900,
#  u'vestment': 52171,
#  u"cabal's'": 54638,
#  u'extent': 2823,
#  u'tendons': 52172,
#  u"heller's": 52173,
#  u'quagmires': 52174,
#  u'miyako': 52175,
#  u'moocow': 20601,
#  u"coles'": 52176,
#  u'lookit': 40895,
#  u'ravenously': 52177,
#  u'levitating': 40896,
#  u'perfunctorily': 52178,
#  u'lookin': 30587,
#  u'thialnd': 88440,
#  u"lot'": 40898,
#  u'lookie': 52179,
#  u'fearlessly': 34870,
#  u'libyan': 52181,
#  u'fondles': 40899,
#  u'gopher': 35714,
#  u'wearying': 40901,
#  u"nz's": 52182,
#  u'minuses': 27646,
#  u'puposelessly': 52183,
#  u'shandling': 52184,
#  u'surname': 23384,
#  u'humming': 11929,
#  u"'nother": 40902,
#  u'smackdown': 21914,
#  u'underdone': 30588,
#  u'frf': 40903,
#  u'triviality': 52185,
#  u'fro': 25248,
#  u'bothers': 8777,
#  u"'kensington": 52186,
#  u'much': 73,
#  u'muco': 34730,
#  u'chink': 27647,
#  u"richie's": 27648,
#  u'tonino': 40904,
#  u'unleavened': 52187,
#  u'fry': 11587,
#  u"'tv'": 40905,
#  u'toning': 40906,
#  u'obese': 14361,
#  u'sensationalized': 30589,
#  u'spiv': 40907,
#  u'spit': 6259,
#  u'fidgetting': 70437,
#  u'arkin': 7364,
#  u'charleton': 21915,
#  u'jeon': 16823,
#  u'boardroom': 21916,
#  u'doubts': 4989,
#  u'spin': 3084,
#  u'skilfully': 30590,
#  u'wildcat': 27649,
#  u'unecessary': 52189,
#  u'misconstrues': 52191,
#  u'mesmerising': 18514,
#  u'misconstrued': 40908,
#  u'rescinds': 52192,
#  u'prostrate': 52193,
#  u'belittling': 47367,
#  u'majid': 40909,
#  u"shock'": 52194,
#  u'canoeing': 34731,
#  u'majin': 52195,
#  u"berkeley's": 21917,
#  u'sylke': 40910,
#  u'conditioned': 14899,
#  u'waddell': 40911,
#  u'hyperdrive': 41188,
#  u'conditioner': 34732,
#  u'hone': 30591,
#  u'hong': 2576,
#  u'memoriam': 52198,
#  u'inventively': 30592,
#  u"levant's": 25249,
#  u'portobello': 20638,
#  u'remand': 52200,
#  u'mummified': 19504,
#  u'honk': 27650,
#  u'spews': 19505,
#  u'visitations': 40912,
#  u'mummifies': 52201,
#  u'cavanaugh': 25250,
#  u'zeon': 23385,
#  u"jungle's": 40913,
#  u'chauvinistic': 19544,
#  u'frenchmen': 27651,
#  u'torpedoes': 52202,
#  u'schlessinger': 52203,
#  u'torpedoed': 34734,
#  u'blister': 69876,
#  u'cinefest': 52204,
#  u'furlough': 34735,
#  u'mainsequence': 52205,
#  u'mentors': 40914,
#  u'academic': 9094,
#  u'stillness': 20602,
#  u'academia': 40915,
#  u'lonelier': 52206,
#  u'nibby': 52207,
#  u"losers'": 52208,
#  u'cineastes': 40916,
#  u'corporate': 4449,
#  u'massaging': 40917,
#  u'bellow': 30593,
#  u'absurdities': 19506,
#  u'expetations': 53241,
#  u'nyfiken': 40918,
#  u'lasse': 52209,
#  u'visability': 52210,
#  u"elder'": 52211,
#  u'gainsbourg': 19023,
#  u'hah': 20603,
#  u'hai': 13420,
#  u'upsides': 53255,
#  u'hak': 25251,
#  u'hal': 4311,
#  u'ham': 4892,
#  u'han': 8058,
#  u'haa': 52213,
#  u'had': 66,
#  u'advancement': 11930,
#  u'hag': 16825,
#  u"hand'": 25252,
#  u'hay': 13421,
#  u'mcnamara': 20604,
#  u"mozart's": 52214,
#  u'hap': 25253,
#  u'haq': 30594,
#  u'har': 13887,
#  u'has': 44,
#  u'hat': 2401,
#  u'hav': 40919,
#  u'haw': 30595,
#  u'cocked': 30596,
#  u'municipal': 34927,
#  u'elders': 15495,
#  u'underpanted': 52216,
#  u'pninson': 52217,
#  u'unequivocally': 27652,
#  u'palazzo': 52218,
#  u"bello'": 52219,
#  u'indicative': 12997,
#  u'yawnfest': 40920,
#  u'hexploitation': 52220,
#  u"loder's": 52221,
#  u'sleuthing': 27653,
#  u'darkon': 40921,
#  u"'ball": 52222,
#  u"'summer": 52223,
#  u"'demons'": 34935,
#  u"mormon's": 52225,
#  u"laughton's": 34737,
#  u'debell': 52226,
#  u'shipyard': 39724,
#  u'unabashedly': 30597,
#  u'disks': 40401,
#  u'crowd': 2290,
#  u'crowe': 10087,
#  u"vancouver's": 56434,
#  u'mosques': 34738,
#  u'crown': 6627,
#  u'culpas': 52227,
#  u'captive': 8428,
#  u'surrell': 53344,
#  u'flowless': 52229,
#  u'sheirk': 52230,
#  u"'three": 40923,
#  u"peterson'": 52231,
#  u'ooverall': 52232,
#  u'perchance': 40924,
#  u'bottom': 1321,
#  u'chabert': 53363,
#  u'sneha': 52233,
#  u'inhuman': 13888,
#  u'ichii': 52234,
#  u'ursla': 52235,
#  u'completly': 30598,
#  u'moviedom': 40925,
#  u'raddick': 52236,
#  u'brigades': 40926,
#  u'stutter': 25254,
#  u'starring': 1181,
#  u"'goal'": 52237,
#  u'caskets': 52238,
#  u'willcock': 52239,
#  u"threesome's": 52240,
#  u"mosque'": 52241,
#  u"cover's": 52242,
#  u'spaceships': 17637,
#  u'anomalous': 40927,
#  u'ptsd': 27655,
#  u'shirdan': 52243,
#  u'gra\xe7a': 51916,
#  u'lemmings': 30599,
#  u'duccio': 30600,
#  u"levene's": 52244,
#  u"'gorby'": 52245,
#  u"teenager's": 25255,
#  u'marshall': 5340,
#  u'honeymoon': 9095,
#  u'shoots': 3231,
#  u'despised': 12258,
#  u'okabasho': 52246,
#  u'fabric': 8289,
#  u'cannavale': 18515,
#  u'raped': 3537,
#  u"tutt's": 52247,
#  u'grasping': 17638,
#  u'despises': 18516,
#  u"thief's": 40928,
#  u'rapes': 8926,
#  u'raper': 52248,
#  u"eyre'": 27656,
#  u'walchek': 52249,
#  u"elmo's": 23386,
#  u'perfumes': 40929,
#  u'spurting': 21918,
#  u'denoting': 52251,
#  u'thesaurus': 34740,
#  u"shoot'": 40930,
#  u'bonejack': 49759,
#  u'simpsonian': 52253,
#  u'hebetude': 30601,
#  u"hallow's": 34741,
#  u'incinerator': 34742,
#  u'congratulations': 10308,
#  u'humbled': 52255,
#  u"else's": 5924,
#  u'trelkovski': 40845,
#  u"rape'": 52256,
#  u'1600s': 52257,
#  u'martian': 7253,
#  u'nicest': 25256,
#  u'eyred': 52259,
#  u'passenger': 9457,
#  u'disgrace': 6041,
#  u'moderne': 52260,
#  u'barrymore': 5120,
#  u'yankovich': 52261,
#  u'moderns': 40931,
#  u'studliest': 52262,
#  u'bedsheet': 52263,
#  u'decapitation': 14900,
#  u'slurring': 52264,
#  u"'nunsploitation'": 52265,
#  u'\x96on': 68949,
#  u"'character'": 34743,
#  u'cambodia': 9880,
#  u'rebelious': 52266,
#  u'pasadena': 27657,
#  u'crowne': 40932,
#  u"'bedchamber": 52267,
#  u'appologize': 52269,
#  u'halfassing': 52270,
#  u'bops': 20605,
#  u'palms': 20606,
#  u"'islands": 52271,
#  u'up\x85oh': 55276,
#  u'hawked': 40933,
#  u'palme': 21919,
#  u'unnervingly': 29285,
#  u'acquaintance': 11589,
#  u'palma': 5558,
#  u'smelling': 21920,
#  u'aragorn': 12998,
#  u'hawker': 52272,
#  u'hawkes': 52273,
#  u'explosions': 3975,
#  u'loren': 8059,
#  u"pyle's": 52274,
#  u'shootout': 6704,
#  u"mike's": 18517,
#  u"driscoll's": 52275,
#  u'cogsworth': 40935,
#  u'shoot\x97': 67168,
#  u"britian's": 52276,
#  u'childs': 34744,
#  u"portrait's": 52277,
#  u'chain': 3626,
#  u'whoever': 2497,
#  u'puttered': 52278,
#  u'childe': 52279,
#  u'maywether': 52280,
#  u'chair': 3036,
#  u"rance's": 52281,
#  u'machu': 34745,
#  u'ballet': 4517,
#  u'grapples': 34746,
#  u'foaming': 40936,
#  u'freelance': 30603,
#  u"andrea's": 52283,
#  u'coolidge': 45879,
#  u'mache': 18518,
#  u'balled': 52285,
#  u'grappled': 40937,
#  u'macha': 18519,
#  u'underlining': 21921,
#  u'macho': 5623,
#  u'oversight': 19507,
#  u'machi': 25257,
#  u'verbally': 11311,
#  u'tenacious': 21922,
#  u'windshields': 40938,
#  u'paychecks': 18557,
#  u'jerk': 3396,
#  u"good'": 11931,
#  u'prancer': 34748,
#  u'prances': 21923,
#  u'olympus': 52286,
#  u'lark': 21924,
#  u'embark': 10785,
#  u'gloomy': 7365,
#  u'blackwood': 14350,
#  u'jehaan': 52287,
#  u'turaqui': 52288,
#  u"child'": 20607,
#  u'\x85\x85\x85': 76046,
#  u'simper': 40939,
#  u'pranced': 52289,
#  u'exact': 2588,
#  u'unattuned': 52290,
#  u'minute': 783,
#  u'skewed': 16118,
#  u'hodgins': 40940,
#  u'skewer': 34749,
#  u'rosenstein': 38765,
#  u'helmit': 52292,
#  u'wrestlemanias': 34750,
#  u'hindered': 16826,
#  u"martha's": 30604,
#  u'cheree': 52293,
#  u"pluckin'": 52294,
#  u'ogles': 40941,
#  u'heavyweight': 11932,
#  u'aada': 82190,
#  u'chopping': 11312,
#  u'hegemonic': 41342,
#  u'adorns': 40942,
#  u'bagging': 36602,
#  u'nobuhiro': 34751,
#  u'kavogianni': 52299,
#  u'antwerp': 13422,
#  u'celebrated': 6538,
#  u'roarke': 52300,
#  u'baggins': 40943,
#  u'paradoxes': 25258,
#  u'matras': 52301,
#  u"nineties'": 52302,
#  u"'craig'": 52303,
#  u'celebrates': 12999,
#  u'unintentionally': 3383,
#  u'drafted': 14362,
#  u'climby': 52304,
#  u'303': 52305,
#  u'oldies': 18520,
#  u'climbs': 9096,
#  u'honour': 9655,
#  u'plucking': 34752,
#  u'305': 30074,
#  u'address': 5514,
#  u'menjou': 40944,
#  u"'freak'": 42592,
#  u'dwindling': 19508,
#  u'benson': 9458,
#  u'shamelessness': 40945,
#  u'impacted': 21925,
#  u'upatz': 52308,
#  u'cusack': 3840,
#  u"flavia's": 37567,
#  u'effette': 52309,
#  u'influx': 34753,
#  u'boooooooo': 52310,
#  u'dimitrova': 52311,
#  u'houseman': 13423,
#  u'bigas': 25259,
#  u'boylen': 52312,
#  u'phillipenes': 52313,
#  u'fakery': 40946,
#  u"grandpa's": 27658,
#  u'darnell': 27659,
#  u'undergone': 19509,
#  u'handbags': 52315,
#  u'perished': 21926,
#  u"jai's": 44587,
#  u'vigour': 27660,
#  u'opposed': 3627,
#  u'etude': 52316,
#  u'doozers': 52317,
#  u'photojournals': 34754,
#  u'perishes': 52318,
#  u'constrains': 34755,
#  u'migenes': 40948,
#  u'consoled': 30605,
#  u'alastair': 16827,
#  u'wvs': 52319,
#  u'ooooooh': 52320,
#  u'approving': 34756,
#  u'consoles': 40949,
#  u'edgeways': 52321,
#  u'futureistic': 52322,
#  u'rebounding': 52323,
#  u'ties': 4294,
#  u"'date": 52324,
#  u'gregoire': 52325,
#  u'rutherford': 21927,
#  u'americanised': 34757,
#  u'novikov': 82196,
#  u'following': 1042,
#  u'munroe': 34758,
#  u"morita'": 52326,
#  u'christenssen': 52327,
#  u'oatmeal': 23106,
#  u'fossey': 25260,
#  u'livered': 40950,
#  u'listens': 13000,
#  u"'marci": 76164,
#  u'cookery': 70459,
#  u'thanking': 23387,
#  u'maude': 16019,
#  u'extensions': 34759,
#  u'fretwell': 42821,
#  u"o'clich\xe9s": 57346,
#  u'convincingly': 4518,
#  u'fueled': 17639,
#  u'mahattan': 54014,
#  u"paris's": 40952,
#  u'justi\xe7a': 60179,
#  u'vulkan': 52336,
#  u'stapes': 52337,
#  u'odysessy': 52338,
#  u'harmon': 12259,
#  u'surfing': 4252,
#  u'unbelieveably': 49580,
#  u"'offed'": 52339,
#  u'finalize': 47158,
#  u'quadrant': 30607,
#  u'inhabiting': 19510,
#  u'nebbish': 34760,
#  u'forebears': 40953,
#  u'skirmish': 34761,
#  u'ocassionally': 52340,
#  u"'resist": 52341,
#  u'impactful': 21928,
#  u'spicier': 52342,
#  u'touristy': 40954,
#  u"'football'": 52343,
#  u'bien': 52344,
#  u'webpage': 40955,
#  u'exurbia': 52345,
#  u'jucier': 52346,
#  u'professors': 14901,
#  u'structuring': 34762,
#  u'jig': 30608,
#  u'overlord': 40956,
#  u'disconnect': 25261,
#  u'sniffle': 82201,
#  u'slimeball': 40957,
#  u'jia': 40958,
#  u'milked': 16828,
#  u'banjoes': 40959,
#  u'jim': 1237,
#  u'workforces': 52348,
#  u'jip': 52349,
#  u'rotweiller': 52350,
#  u'mundaneness': 34763,
#  u"'ninja'": 52351,
#  u"dead'": 11040,
#  u"cipriani's": 40960,
#  u'modestly': 20608,
#  u"professor'": 52352,
#  u'shacked': 40961,
#  u'bashful': 34764,
#  u'sorter': 23388,
#  u'overpowering': 16120,
#  u'workmanlike': 18521,
#  u'henpecked': 27662,
#  u'sorted': 18522,
#  u"'always": 52355,
#  u"'baptists": 34765,
#  u'dreamcatchers': 52356,
#  u"'silence'": 52357,
#  u'hickory': 21929,
#  u'ladysmith': 54111,
#  u'breakumentary': 52359,
#  u'didn': 15496,
#  u'didi': 52360,
#  u'pealing': 52361,
#  u'dispite': 40962,
#  u"italy's": 25262,
#  u'instability': 21930,
#  u'quarter': 6539,
#  u'quartet': 12608,
#  u'did\x85': 79736,
#  u"'bleedmedry": 52363,
#  u'pahalniuk': 52364,
#  u'honduras': 52365,
#  u'bursting': 10786,
#  u"pablo's": 41465,
#  u'irremediably': 52367,
#  u'presages': 40963,
#  u'bowlegged': 57832,
#  u'entering': 6260,
#  u'newsradio': 76172,
#  u'disasters': 8927,
#  u"giallo's": 27663,
#  u'bouyant': 40964,
#  u'amerterish': 52368,
#  u'rajni': 18523,
#  u'leeves': 30610,
#  u'macauley': 34767,
#  u'seriously': 612,
#  u'sugercoma': 52369,
#  u'grimstead': 52370,
#  u'xena': 28281,
#  u"'fairy'": 52371,
#  u'zenda': 30611,
#  u"'twins'": 52372,
#  u'realisation': 17640,
#  u"resident's": 70464,
#  u'raunchy': 7817,
#  u'incentives': 40965,
#  u'sonar': 76174,
#  u'inwardly': 27665,
#  u'crazies': 16829,
#  u'crazier': 14902,
#  u'grandma': 7094,
#  u'napunsaktha': 52375,
#  u'workmanship': 30612,
#  u'reisner': 52376,
#  u"sanford's": 61306,
#  u'modest': 6108,
#  u"everything's": 19153,
#  u'hamer': 40966,
#  u"couldn't'": 52379,
#  u'quibble': 13001,
#  u'socking': 52380,
#  u'tingler': 21931,
#  u'gutman': 52381,
#  u'interviewer': 19011,
#  u'lachlan': 40967,
#  u'tableaus': 52382,
#  u'headbanger': 52383,
#  u'spoken': 2847,
#  u'twined': 70466,
#  u"'road": 23490,
#  u'tableaux': 21932,
#  u'\xa39': 72557,
#  u'\xa38': 72556,
#  u"proust's": 40968,
#  u'periodical': 40969,
#  u"shoveller's": 52385,
#  u'\xa33': 22458,
#  u'\xa32': 32852,
#  u'\xa31': 15842,
#  u'\xa30': 72559,
#  u'\xa37': 72558,
#  u'\xa36': 47111,
#  u'affords': 17641,
#  u'\xa34': 29300,
#  u'zo\xe9': 36033,
#  u'sloane\x85': 78264,
#  u"yara's": 87955,
#  u'someome': 52386,
#  u'lingering': 8424,
#  u"abraham's": 41511,
#  u'beesley': 34769,
#  u'cherbourg': 34770,
#  u'kagan': 28624,
#  u'snatch': 9097,
#  ...}

# %%
reverse_word_index = dict([(value,key) for (key,value) in word_index.items()])

# %%
reverse_word_index
# Out:
# {1: u'the',
#  2: u'and',
#  3: u'a',
#  4: u'of',
#  5: u'to',
#  6: u'is',
#  7: u'br',
#  8: u'in',
#  9: u'it',
#  10: u'i',
#  11: u'this',
#  12: u'that',
#  13: u'was',
#  14: u'as',
#  15: u'for',
#  16: u'with',
#  17: u'movie',
#  18: u'but',
#  19: u'film',
#  20: u'on',
#  21: u'not',
#  22: u'you',
#  23: u'are',
#  24: u'his',
#  25: u'have',
#  26: u'he',
#  27: u'be',
#  28: u'one',
#  29: u'all',
#  30: u'at',
#  31: u'by',
#  32: u'an',
#  33: u'they',
#  34: u'who',
#  35: u'so',
#  36: u'from',
#  37: u'like',
#  38: u'her',
#  39: u'or',
#  40: u'just',
#  41: u'about',
#  42: u"it's",
#  43: u'out',
#  44: u'has',
#  45: u'if',
#  46: u'some',
#  47: u'there',
#  48: u'what',
#  49: u'good',
#  50: u'more',
#  51: u'when',
#  52: u'very',
#  53: u'up',
#  54: u'no',
#  55: u'time',
#  56: u'she',
#  57: u'even',
#  58: u'my',
#  59: u'would',
#  60: u'which',
#  61: u'only',
#  62: u'story',
#  63: u'really',
#  64: u'see',
#  65: u'their',
#  66: u'had',
#  67: u'can',
#  68: u'were',
#  69: u'me',
#  70: u'well',
#  71: u'than',
#  72: u'we',
#  73: u'much',
#  74: u'been',
#  75: u'bad',
#  76: u'get',
#  77: u'will',
#  78: u'do',
#  79: u'also',
#  80: u'into',
#  81: u'people',
#  82: u'other',
#  83: u'first',
#  84: u'great',
#  85: u'because',
#  86: u'how',
#  87: u'him',
#  88: u'most',
#  89: u"don't",
#  90: u'made',
#  91: u'its',
#  92: u'then',
#  93: u'way',
#  94: u'make',
#  95: u'them',
#  96: u'too',
#  97: u'could',
#  98: u'any',
#  99: u'movies',
#  100: u'after',
#  101: u'think',
#  102: u'characters',
#  103: u'watch',
#  104: u'two',
#  105: u'films',
#  106: u'character',
#  107: u'seen',
#  108: u'many',
#  109: u'being',
#  110: u'life',
#  111: u'plot',
#  112: u'never',
#  113: u'acting',
#  114: u'little',
#  115: u'best',
#  116: u'love',
#  117: u'over',
#  118: u'where',
#  119: u'did',
#  120: u'show',
#  121: u'know',
#  122: u'off',
#  123: u'ever',
#  124: u'does',
#  125: u'better',
#  126: u'your',
#  127: u'end',
#  128: u'still',
#  129: u'man',
#  130: u'here',
#  131: u'these',
#  132: u'say',
#  133: u'scene',
#  134: u'while',
#  135: u'why',
#  136: u'scenes',
#  137: u'go',
#  138: u'such',
#  139: u'something',
#  140: u'through',
#  141: u'should',
#  142: u'back',
#  143: u"i'm",
#  144: u'real',
#  145: u'those',
#  146: u'watching',
#  147: u'now',
#  148: u'though',
#  149: u"doesn't",
#  150: u'years',
#  151: u'old',
#  152: u'thing',
#  153: u'actors',
#  154: u'work',
#  155: u'10',
#  156: u'before',
#  157: u'another',
#  158: u"didn't",
#  159: u'new',
#  160: u'funny',
#  161: u'nothing',
#  162: u'actually',
#  163: u'makes',
#  164: u'director',
#  165: u'look',
#  166: u'find',
#  167: u'going',
#  168: u'few',
#  169: u'same',
#  170: u'part',
#  171: u'again',
#  172: u'every',
#  173: u'lot',
#  174: u'cast',
#  175: u'us',
#  176: u'quite',
#  177: u'down',
#  178: u'want',
#  179: u'world',
#  180: u'things',
#  181: u'pretty',
#  182: u'young',
#  183: u'seems',
#  184: u'around',
#  185: u'got',
#  186: u'horror',
#  187: u'however',
#  188: u"can't",
#  189: u'fact',
#  190: u'take',
#  191: u'big',
#  192: u'enough',
#  193: u'long',
#  194: u'thought',
#  195: u"that's",
#  196: u'both',
#  197: u'between',
#  198: u'series',
#  199: u'give',
#  200: u'may',
#  201: u'original',
#  202: u'own',
#  203: u'action',
#  204: u"i've",
#  205: u'right',
#  206: u'without',
#  207: u'always',
#  208: u'times',
#  209: u'comedy',
#  210: u'point',
#  211: u'gets',
#  212: u'must',
#  213: u'come',
#  214: u'role',
#  215: u"isn't",
#  216: u'saw',
#  217: u'almost',
#  218: u'interesting',
#  219: u'least',
#  220: u'family',
#  221: u'done',
#  222: u"there's",
#  223: u'whole',
#  224: u'bit',
#  225: u'music',
#  226: u'script',
#  227: u'far',
#  228: u'making',
#  229: u'guy',
#  230: u'anything',
#  231: u'minutes',
#  232: u'feel',
#  233: u'last',
#  234: u'since',
#  235: u'might',
#  236: u'performance',
#  237: u"he's",
#  238: u'2',
#  239: u'probably',
#  240: u'kind',
#  241: u'am',
#  242: u'away',
#  243: u'yet',
#  244: u'rather',
#  245: u'tv',
#  246: u'worst',
#  247: u'girl',
#  248: u'day',
#  249: u'sure',
#  250: u'fun',
#  251: u'hard',
#  252: u'woman',
#  253: u'played',
#  254: u'each',
#  255: u'found',
#  256: u'anyone',
#  257: u'having',
#  258: u'although',
#  259: u'especially',
#  260: u'our',
#  261: u'believe',
#  262: u'course',
#  263: u'comes',
#  264: u'looking',
#  265: u'screen',
#  266: u'trying',
#  267: u'set',
#  268: u'goes',
#  269: u'looks',
#  270: u'place',
#  271: u'book',
#  272: u'different',
#  273: u'put',
#  274: u'ending',
#  275: u'money',
#  276: u'maybe',
#  277: u'once',
#  278: u'sense',
#  279: u'reason',
#  280: u'true',
#  281: u'actor',
#  282: u'everything',
#  283: u"wasn't",
#  284: u'shows',
#  285: u'dvd',
#  286: u'three',
#  287: u'worth',
#  288: u'year',
#  289: u'job',
#  290: u'main',
#  291: u'someone',
#  292: u'together',
#  293: u'watched',
#  294: u'play',
#  295: u'american',
#  296: u'plays',
#  297: u'1',
#  298: u'said',
#  299: u'effects',
#  300: u'later',
#  301: u'takes',
#  302: u'instead',
#  303: u'seem',
#  304: u'beautiful',
#  305: u'john',
#  306: u'himself',
#  307: u'version',
#  308: u'audience',
#  309: u'high',
#  310: u'house',
#  311: u'night',
#  312: u'during',
#  313: u'everyone',
#  314: u'left',
#  315: u'special',
#  316: u'seeing',
#  317: u'half',
#  318: u'excellent',
#  319: u'wife',
#  320: u'star',
#  321: u'shot',
#  322: u'war',
#  323: u'idea',
#  324: u'nice',
#  325: u'black',
#  326: u'less',
#  327: u'mind',
#  328: u'simply',
#  329: u'read',
#  330: u'second',
#  331: u'else',
#  332: u"you're",
#  333: u'father',
#  334: u'fan',
#  335: u'poor',
#  336: u'help',
#  337: u'completely',
#  338: u'death',
#  339: u'3',
#  340: u'used',
#  341: u'home',
#  342: u'either',
#  343: u'short',
#  344: u'line',
#  345: u'given',
#  346: u'men',
#  347: u'top',
#  348: u'dead',
#  349: u'budget',
#  350: u'try',
#  351: u'performances',
#  352: u'wrong',
#  353: u'classic',
#  354: u'boring',
#  355: u'enjoy',
#  356: u'need',
#  357: u'rest',
#  358: u'use',
#  359: u'kids',
#  360: u'hollywood',
#  361: u'low',
#  362: u'production',
#  363: u'until',
#  364: u'along',
#  365: u'full',
#  366: u'friends',
#  367: u'camera',
#  368: u'truly',
#  369: u'women',
#  370: u'awful',
#  371: u'video',
#  372: u'next',
#  373: u'tell',
#  374: u'remember',
#  375: u'couple',
#  376: u'stupid',
#  377: u'start',
#  378: u'stars',
#  379: u'perhaps',
#  380: u'sex',
#  381: u'mean',
#  382: u'came',
#  383: u'recommend',
#  384: u'let',
#  385: u'moments',
#  386: u'wonderful',
#  387: u'episode',
#  388: u'understand',
#  389: u'small',
#  390: u'face',
#  391: u'terrible',
#  392: u'playing',
#  393: u'school',
#  394: u'getting',
#  395: u'written',
#  396: u'doing',
#  397: u'often',
#  398: u'keep',
#  399: u'early',
#  400: u'name',
#  401: u'perfect',
#  402: u'style',
#  403: u'human',
#  404: u'definitely',
#  405: u'gives',
#  406: u'others',
#  407: u'itself',
#  408: u'lines',
#  409: u'live',
#  410: u'become',
#  411: u'dialogue',
#  412: u'person',
#  413: u'lost',
#  414: u'finally',
#  415: u'piece',
#  416: u'head',
#  417: u'case',
#  418: u'felt',
#  419: u'yes',
#  420: u'liked',
#  421: u'supposed',
#  422: u'title',
#  423: u"couldn't",
#  424: u'absolutely',
#  425: u'white',
#  426: u'against',
#  427: u'boy',
#  428: u'picture',
#  429: u'sort',
#  430: u'worse',
#  431: u'certainly',
#  432: u'went',
#  433: u'entire',
#  434: u'waste',
#  435: u'cinema',
#  436: u'problem',
#  437: u'hope',
#  438: u'entertaining',
#  439: u"she's",
#  440: u'mr',
#  441: u'overall',
#  442: u'evil',
#  443: u'called',
#  444: u'loved',
#  445: u'based',
#  446: u'oh',
#  447: u'several',
#  448: u'fans',
#  449: u'mother',
#  450: u'drama',
#  451: u'beginning',
#  452: u'killer',
#  453: u'lives',
#  454: u'5',
#  455: u'direction',
#  456: u'care',
#  457: u'already',
#  458: u'becomes',
#  459: u'laugh',
#  460: u'example',
#  461: u'friend',
#  462: u'dark',
#  463: u'despite',
#  464: u'under',
#  465: u'seemed',
#  466: u'throughout',
#  467: u'4',
#  468: u'turn',
#  469: u'unfortunately',
#  470: u'wanted',
#  471: u"i'd",
#  472: u'\x96',
#  473: u'children',
#  474: u'final',
#  475: u'fine',
#  476: u'history',
#  477: u'amazing',
#  478: u'sound',
#  479: u'guess',
#  480: u'heart',
#  481: u'totally',
#  482: u'lead',
#  483: u'humor',
#  484: u'writing',
#  485: u'michael',
#  486: u'quality',
#  487: u"you'll",
#  488: u'close',
#  489: u'son',
#  490: u'guys',
#  491: u'wants',
#  492: u'works',
#  493: u'behind',
#  494: u'tries',
#  495: u'art',
#  496: u'side',
#  497: u'game',
#  498: u'past',
#  499: u'able',
#  500: u'b',
#  501: u'days',
#  502: u'turns',
#  503: u'child',
#  504: u"they're",
#  505: u'hand',
#  506: u'flick',
#  507: u'enjoyed',
#  508: u'act',
#  509: u'genre',
#  510: u'town',
#  511: u'favorite',
#  512: u'soon',
#  513: u'kill',
#  514: u'starts',
#  515: u'sometimes',
#  516: u'car',
#  517: u'gave',
#  518: u'run',
#  519: u'late',
#  520: u'eyes',
#  521: u'actress',
#  522: u'etc',
#  523: u'directed',
#  524: u'horrible',
#  525: u"won't",
#  526: u'viewer',
#  527: u'brilliant',
#  528: u'parts',
#  529: u'self',
#  530: u'themselves',
#  531: u'hour',
#  532: u'expect',
#  533: u'thinking',
#  534: u'stories',
#  535: u'stuff',
#  536: u'girls',
#  537: u'obviously',
#  538: u'blood',
#  539: u'decent',
#  540: u'city',
#  541: u'voice',
#  542: u'highly',
#  543: u'myself',
#  544: u'feeling',
#  545: u'fight',
#  546: u'except',
#  547: u'slow',
#  548: u'matter',
#  549: u'type',
#  550: u'anyway',
#  551: u'kid',
#  552: u'roles',
#  553: u'killed',
#  554: u'heard',
#  555: u'god',
#  556: u'age',
#  557: u'says',
#  558: u'moment',
#  559: u'took',
#  560: u'leave',
#  561: u'writer',
#  562: u'strong',
#  563: u'cannot',
#  564: u'violence',
#  565: u'police',
#  566: u'hit',
#  567: u'stop',
#  568: u'happens',
#  569: u'particularly',
#  570: u'known',
#  571: u'involved',
#  572: u'happened',
#  573: u'extremely',
#  574: u'daughter',
#  575: u'obvious',
#  576: u'told',
#  577: u'chance',
#  578: u'living',
#  579: u'coming',
#  580: u'lack',
#  581: u'alone',
#  582: u'experience',
#  583: u"wouldn't",
#  584: u'including',
#  585: u'murder',
#  586: u'attempt',
#  587: u's',
#  588: u'please',
#  589: u'james',
#  590: u'happen',
#  591: u'wonder',
#  592: u'crap',
#  593: u'ago',
#  594: u'brother',
#  595: u"film's",
#  596: u'gore',
#  597: u'none',
#  598: u'complete',
#  599: u'interest',
#  600: u'score',
#  601: u'group',
#  602: u'cut',
#  603: u'simple',
#  604: u'save',
#  605: u'ok',
#  606: u'hell',
#  607: u'looked',
#  608: u'career',
#  609: u'number',
#  610: u'song',
#  611: u'possible',
#  612: u'seriously',
#  613: u'annoying',
#  614: u'shown',
#  615: u'exactly',
#  616: u'sad',
#  617: u'running',
#  618: u'musical',
#  619: u'serious',
#  620: u'taken',
#  621: u'yourself',
#  622: u'whose',
#  623: u'released',
#  624: u'cinematography',
#  625: u'david',
#  626: u'scary',
#  627: u'ends',
#  628: u'english',
#  629: u'hero',
#  630: u'usually',
#  631: u'hours',
#  632: u'reality',
#  633: u'opening',
#  634: u"i'll",
#  635: u'across',
#  636: u'today',
#  637: u'jokes',
#  638: u'light',
#  639: u'hilarious',
#  640: u'somewhat',
#  641: u'usual',
#  642: u'started',
#  643: u'cool',
#  644: u'ridiculous',
#  645: u'body',
#  646: u'relationship',
#  647: u'view',
#  648: u'level',
#  649: u'opinion',
#  650: u'change',
#  651: u'happy',
#  652: u'middle',
#  653: u'taking',
#  654: u'wish',
#  655: u'husband',
#  656: u'finds',
#  657: u'saying',
#  658: u'order',
#  659: u'talking',
#  660: u'ones',
#  661: u'documentary',
#  662: u'shots',
#  663: u'huge',
#  664: u'novel',
#  665: u'female',
#  666: u'mostly',
#  667: u'robert',
#  668: u'power',
#  669: u'episodes',
#  670: u'room',
#  671: u'important',
#  672: u'rating',
#  673: u'talent',
#  674: u'five',
#  675: u'major',
#  676: u'turned',
#  677: u'strange',
#  678: u'word',
#  679: u'modern',
#  680: u'call',
#  681: u'apparently',
#  682: u'disappointed',
#  683: u'single',
#  684: u'events',
#  685: u'due',
#  686: u'four',
#  687: u'songs',
#  688: u'basically',
#  689: u'attention',
#  690: u'7',
#  691: u'knows',
#  692: u'clearly',
#  693: u'supporting',
#  694: u'knew',
#  695: u'british',
#  696: u'television',
#  697: u'comic',
#  698: u'non',
#  699: u'fast',
#  700: u'earth',
#  701: u'country',
#  702: u'future',
#  703: u'cheap',
#  704: u'class',
#  705: u'thriller',
#  706: u'8',
#  707: u'silly',
#  708: u'king',
#  709: u'problems',
#  710: u"aren't",
#  711: u'easily',
#  712: u'words',
#  713: u'tells',
#  714: u'miss',
#  715: u'jack',
#  716: u'local',
#  717: u'sequence',
#  718: u'bring',
#  719: u'entertainment',
#  720: u'paul',
#  721: u'beyond',
#  722: u'upon',
#  723: u'whether',
#  724: u'predictable',
#  725: u'moving',
#  726: u'similar',
#  727: u'straight',
#  728: u'romantic',
#  729: u'sets',
#  730: u'review',
#  731: u'falls',
#  732: u'oscar',
#  733: u'mystery',
#  734: u'enjoyable',
#  735: u'needs',
#  736: u'appears',
#  737: u'talk',
#  738: u'rock',
#  739: u'george',
#  740: u'giving',
#  741: u'eye',
#  742: u'richard',
#  743: u'within',
#  744: u'ten',
#  745: u'animation',
#  746: u'message',
#  747: u'theater',
#  748: u'near',
#  749: u'above',
#  750: u'dull',
#  751: u'nearly',
#  752: u'sequel',
#  753: u'theme',
#  754: u'points',
#  755: u"'",
#  756: u'stand',
#  757: u'mention',
#  758: u'lady',
#  759: u'bunch',
#  760: u'add',
#  761: u'feels',
#  762: u'herself',
#  763: u'release',
#  764: u'red',
#  765: u'team',
#  766: u'storyline',
#  767: u'surprised',
#  768: u'ways',
#  769: u'using',
#  770: u'named',
#  771: u"haven't",
#  772: u'lots',
#  773: u'easy',
#  774: u'fantastic',
#  775: u'begins',
#  776: u'actual',
#  777: u'working',
#  778: u'effort',
#  779: u'york',
#  780: u'die',
#  781: u'hate',
#  782: u'french',
#  783: u'minute',
#  784: u'tale',
#  785: u'clear',
#  786: u'stay',
#  787: u'9',
#  788: u'elements',
#  789: u'feature',
#  790: u'among',
#  791: u'follow',
#  792: u'comments',
#  793: u're',
#  794: u'viewers',
#  795: u'avoid',
#  796: u'sister',
#  797: u'showing',
#  798: u'typical',
#  799: u'editing',
#  800: u"what's",
#  801: u'famous',
#  802: u'tried',
#  803: u'sorry',
#  804: u'dialog',
#  805: u'check',
#  806: u'fall',
#  807: u'period',
#  808: u'season',
#  809: u'form',
#  810: u'certain',
#  811: u'filmed',
#  812: u'weak',
#  813: u'soundtrack',
#  814: u'means',
#  815: u'buy',
#  816: u'material',
#  817: u'somehow',
#  818: u'realistic',
#  819: u'figure',
#  820: u'crime',
#  821: u'doubt',
#  822: u'gone',
#  823: u'peter',
#  824: u'tom',
#  825: u'kept',
#  826: u'viewing',
#  827: u't',
#  828: u'general',
#  829: u'leads',
#  830: u'greatest',
#  831: u'space',
#  832: u'lame',
#  833: u'suspense',
#  834: u'dance',
#  835: u'imagine',
#  836: u'brought',
#  837: u'third',
#  838: u'atmosphere',
#  839: u'hear',
#  840: u'particular',
#  841: u'sequences',
#  842: u'whatever',
#  843: u'parents',
#  844: u'move',
#  845: u'lee',
#  846: u'indeed',
#  847: u'learn',
#  848: u'rent',
#  849: u'de',
#  850: u'eventually',
#  851: u'note',
#  852: u'deal',
#  853: u'average',
#  854: u'reviews',
#  855: u'wait',
#  856: u'forget',
#  857: u'japanese',
#  858: u'sexual',
#  859: u'poorly',
#  860: u'premise',
#  861: u'okay',
#  862: u'zombie',
#  863: u'surprise',
#  864: u'believable',
#  865: u'stage',
#  866: u'possibly',
#  867: u'sit',
#  868: u"who's",
#  869: u'decided',
#  870: u'expected',
#  871: u"you've",
#  872: u'subject',
#  873: u'nature',
#  874: u'became',
#  875: u'difficult',
#  876: u'free',
#  877: u'killing',
#  878: u'screenplay',
#  879: u'truth',
#  880: u'romance',
#  881: u'dr',
#  882: u'nor',
#  883: u'reading',
#  884: u'needed',
#  885: u'question',
#  886: u'leaves',
#  887: u'street',
#  888: u'20',
#  889: u'meets',
#  890: u'hot',
#  891: u'unless',
#  892: u'begin',
#  893: u'baby',
#  894: u'superb',
#  895: u'credits',
#  896: u'imdb',
#  897: u'otherwise',
#  898: u'write',
#  899: u'shame',
#  900: u"let's",
#  901: u'situation',
#  902: u'dramatic',
#  903: u'memorable',
#  904: u'directors',
#  905: u'earlier',
#  906: u'meet',
#  907: u'disney',
#  908: u'open',
#  909: u'dog',
#  910: u'badly',
#  911: u'joe',
#  912: u'male',
#  913: u'weird',
#  914: u'acted',
#  915: u'forced',
#  916: u'laughs',
#  917: u'sci',
#  918: u'emotional',
#  919: u'older',
#  920: u'realize',
#  921: u'fi',
#  922: u'dream',
#  923: u'society',
#  924: u'writers',
#  925: u'interested',
#  926: u'footage',
#  927: u'forward',
#  928: u'comment',
#  929: u'crazy',
#  930: u'deep',
#  931: u'sounds',
#  932: u'plus',
#  933: u'beauty',
#  934: u'whom',
#  935: u'america',
#  936: u'fantasy',
#  937: u'directing',
#  938: u'keeps',
#  939: u'ask',
#  940: u'development',
#  941: u'features',
#  942: u'air',
#  943: u'quickly',
#  944: u'mess',
#  945: u'creepy',
#  946: u'towards',
#  947: u'perfectly',
#  948: u'mark',
#  949: u'worked',
#  950: u'box',
#  951: u'cheesy',
#  952: u'unique',
#  953: u'setting',
#  954: u'hands',
#  955: u'plenty',
#  956: u'result',
#  957: u'previous',
#  958: u'brings',
#  959: u'effect',
#  960: u'e',
#  961: u'total',
#  962: u'personal',
#  963: u'incredibly',
#  964: u'rate',
#  965: u'fire',
#  966: u'monster',
#  967: u'business',
#  968: u'leading',
#  969: u'apart',
#  970: u'casting',
#  971: u'admit',
#  972: u'joke',
#  973: u'powerful',
#  974: u'appear',
#  975: u'background',
#  976: u'telling',
#  977: u'girlfriend',
#  978: u'meant',
#  979: u'christmas',
#  980: u'hardly',
#  981: u'present',
#  982: u'battle',
#  983: u'potential',
#  984: u'create',
#  985: u'bill',
#  986: u'break',
#  987: u'pay',
#  988: u'masterpiece',
#  989: u'gay',
#  990: u'political',
#  991: u'return',
#  992: u'dumb',
#  993: u'fails',
#  994: u'fighting',
#  995: u'various',
#  996: u'era',
#  997: u'portrayed',
#  998: u'co',
#  999: u'cop',
#  1000: u'secret',
#  ...}

# %%
decoded_review = ' '.join([reverse_word_index.get(i,'?') for i in x_train[0]])

# %%
decoded_review
# Out:
# u"? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? the as you with out themselves powerful lets loves their becomes reaching had journalist of lot from anyone to have after out atmosphere never more room and it so heart shows to years of every never going and help moments or of every chest visual movie except her was several of enough more with is now current film as you of mine potentially unfortunately of you than him that with out themselves her get for was camp of you movie sometimes movie that with scary but and to story wonderful that in seeing in character to of 70s musicians with heart had shadows they of here that with her serious to have does when from why what have critics they is you that isn't one will very to as itself with other and in of seen over landed for anyone of and br show's to whether from than out themselves history he name half some br of and odd was two most of mean for 1 any an boat she he should is thought frog but of script you not while history he heart to real at barrel but when from one bit then have two of script their with her nobody most that with wasn't to with armed acting watch an for with heartfelt film want an"

# %% [markdown]
# ## Build Keras Embedding Layer Model
# We can think of the Embedding layer as a dicionary that maps a index assigned to a word to a word vector. This layer is very flexible and can be used in a few ways:
#
# * The embedding layer can be used at the start of a larger deep learning model.
# * Also we could load pre-train word embeddings into the embedding layer when we create our model.
# * Use the embedding layer to train our own word2vec models.
#
# The keras embedding layer doesn't require us to onehot encode our words, instead we have to give each word a unqiue intger number as an id. For the imdb dataset we've loaded this has already been done, but if this wasn't the case we could use sklearn [LabelEncoder](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html).

# %%
from keras.models import Sequential
from keras.layers import Flatten,Dense,Embedding

# %%
#define a Embedding Layer with 64 dimensions and input_length = 300 words

# %%
model = Sequential()
model.add(Embedding(10000,64,input_length=
                    maxlen))
model.add(Flatten())
model.add(Dense(32,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
# Out:
# W0104 17:57:51.345451 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0104 17:57:51.355986 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0104 17:57:51.360774 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0104 17:57:51.402538 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0104 17:57:51.418385 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0104 17:57:51.422164 139876623099776 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
history = model.fit(x_train,y_train,
          epochs=20,
          batch_size=32,          
          validation_data=(x_test, y_test))
# Out:
# W0104 17:57:53.757633 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0104 17:57:53.785254 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W0104 17:57:53.832523 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0104 17:57:53.838604 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0104 17:57:53.840030 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# W0104 17:57:55.258111 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W0104 17:57:55.259315 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W0104 17:57:55.346569 139876623099776 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# 25000/25000 [==============================] - 14s 542us/step - loss: 0.3926 - acc: 0.8125 - val_loss: 0.3526 - val_acc: 0.8418
# Epoch 2/20
# 25000/25000 [==============================] - 4s 179us/step - loss: 0.1229 - acc: 0.9554 - val_loss: 0.3849 - val_acc: 0.8547
# Epoch 3/20
# 25000/25000 [==============================] - 4s 179us/step - loss: 0.0220 - acc: 0.9937 - val_loss: 0.5668 - val_acc: 0.8502
# Epoch 4/20
# 25000/25000 [==============================] - 4s 175us/step - loss: 0.0028 - acc: 0.9991 - val_loss: 0.8242 - val_acc: 0.8368
# Epoch 5/20
# 25000/25000 [==============================] - 4s 167us/step - loss: 5.9955e-04 - acc: 0.9998 - val_loss: 1.0086 - val_acc: 0.8326
# Epoch 6/20
# 25000/25000 [==============================] - 4s 166us/step - loss: 5.0932e-06 - acc: 1.0000 - val_loss: 1.1629 - val_acc: 0.8372
# Epoch 7/20
# 25000/25000 [==============================] - 4s 170us/step - loss: 6.1370e-07 - acc: 1.0000 - val_loss: 1.2698 - val_acc: 0.8316
# Epoch 8/20
# 25000/25000 [==============================] - 4s 172us/step - loss: 1.1541e-07 - acc: 1.0000 - val_loss: 1.2835 - val_acc: 0.8334
# Epoch 9/20
# 25000/25000 [==============================] - 4s 168us/step - loss: 1.1021e-07 - acc: 1.0000 - val_loss: 1.2860 - val_acc: 0.8336
# Epoch 10/20
# 25000/25000 [==============================] - 4s 166us/step - loss: 1.0978e-07 - acc: 1.0000 - val_loss: 1.2903 - val_acc: 0.8340
# Epoch 11/20
# 25000/25000 [==============================] - 4s 167us/step - loss: 1.0965e-07 - acc: 1.0000 - val_loss: 1.2931 - val_acc: 0.8329
# Epoch 12/20
# 25000/25000 [==============================] - 4s 169us/step - loss: 1.0969e-07 - acc: 1.0000 - val_loss: 1.2936 - val_acc: 0.8340
# Epoch 13/20
# 25000/25000 [==============================] - 4s 171us/step - loss: 1.0966e-07 - acc: 1.0000 - val_loss: 1.2957 - val_acc: 0.8341
# Epoch 14/20
# 25000/25000 [==============================] - 4s 169us/step - loss: 1.0962e-07 - acc: 1.0000 - val_loss: 1.2978 - val_acc: 0.8338
# Epoch 15/20
# 25000/25000 [==============================] - 4s 164us/step - loss: 1.0963e-07 - acc: 1.0000 - val_loss: 1.2965 - val_acc: 0.8340
# Epoch 16/20
# 25000/25000 [==============================] - 4s 173us/step - loss: 1.0962e-07 - acc: 1.0000 - val_loss: 1.2988 - val_acc: 0.8336
# Epoch 17/20
# 25000/25000 [==============================] - 4s 172us/step - loss: 1.0962e-07 - acc: 1.0000 - val_loss: 1.2984 - val_acc: 0.8333
# Epoch 18/20
# 25000/25000 [==============================] - 4s 168us/step - loss: 1.0963e-07 - acc: 1.0000 - val_loss: 1.2987 - val_acc: 0.8342
# Epoch 19/20
# 25000/25000 [==============================] - 4s 164us/step - loss: 1.0962e-07 - acc: 1.0000 - val_loss: 1.2994 - val_acc: 0.8337
# Epoch 20/20
# 25000/25000 [==============================] - 4s 167us/step - loss: 1.0961e-07 - acc: 1.0000 - val_loss: 1.2990 - val_acc: 0.8339

# %%
#Report the Accuracy of the model. (5 points)

# %%
loss,acc=model.evaluate(x_test,y_test)
print(acc)
# Out:
# 25000/25000 [==============================] - 1s 48us/step
# 0.83392

# %% [markdown]
# ## Retrive the output of each layer in keras for a given single test sample from the trained model you built

# %%
from keras import backend as K

# %%
inp = model.input                                           
outputs = [layer.output for layer in model.layers]          
functors = [K.function([inp], [out]) for out in outputs]   

layer_outs = [func([x_test[0].reshape(1,-1)]) for func in functors]
print layer_outs
# Out:
# [[array([[[-0.00194268, -0.00765159, -0.03504343, ..., -0.01325203,
#          -0.00606479, -0.01482375],
#         [-0.00194268, -0.00765159, -0.03504343, ..., -0.01325203,
#          -0.00606479, -0.01482375],
#         [-0.00194268, -0.00765159, -0.03504343, ..., -0.01325203,
#          -0.00606479, -0.01482375],
#         ...,
#         [ 0.02786462, -0.05064026, -0.01322706, ...,  0.02633499,
#           0.06181337,  0.02612353],
#         [ 0.00236842, -0.01174042,  0.0017697 , ...,  0.01354748,
#          -0.01293511, -0.00688689],
#         [-0.01816829,  0.07322223, -0.12703255, ..., -0.03705573,
#           0.04132452, -0.14361395]]], dtype=float32)], [array([[-0.00194268, -0.00765159, -0.03504343, ..., -0.03705573,
#          0.04132452, -0.14361395]], dtype=float32)], [array([[1.5859357 , 1.725853  , 2.160128  , 1.7440513 , 2.5747254 ,
#         1.5254537 , 1.5868578 , 1.3690289 , 1.9937618 , 1.508213  ,
#         0.52547157, 1.7538209 , 0.35309103, 1.3072786 , 1.6660818 ,
#         1.6598849 , 1.7008424 , 1.5455184 , 1.6941369 , 1.7046121 ,
#         1.7193987 , 1.5590199 , 1.7217786 , 1.5399116 , 1.3005599 ,
#         1.5840279 , 1.1052614 , 0.92225116, 1.7564275 , 1.6554979 ,
#         1.7251352 , 1.3771374 ]], dtype=float32)], [array([[5.801206e-07]], dtype=float32)]]
